# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilioSantiagoCS/Extracci-n-de-Datos/blob/main/Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f49425d9-ca51-46fb-9744-b2125d0346ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f49425d9-ca51-46fb-9744-b2125d0346ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Convertir en dataframe
df = pd.read_csv("CountryTable.csv")
#df

# %%
#Imprimimos las primeras filas o registros del Dataframe
df.head(5)
# Out:
#   code         name      continent                     region  surface_area  \
# 0  ABW        Aruba  North America                  Caribbean         193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia      652090.0
# 2  AGO       Angola         Africa             Central Africa     1246700.0
# 3  AIA     Anguilla  North America                  Caribbean          96.0
# 4  ALB      Albania         Europe            Southern Europe       28748.0
#
#    independence_year  population  life_expectancy     gnp  gnp_old  \
# 0                NaN      103000             78.4   828.0    793.0
# 1             1919.0    22720000             45.9  5976.0      NaN
# 2             1975.0    12878000             38.3  6648.0   7984.0
# 3                NaN        8000             76.1    63.2      NaN
# 4             1912.0     3401200             71.6  3205.0   2500.0
#
#               local_name                               government_form  \
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUALITATIVAS**

# %%
#Filtro por objeto
filtro1=df[df["region"] == "North America"]
filtro1
#SE FILTRAN LOS DATOS PARA SOLO OBSERVAR LOS PAÍSES QUE PERTENECEN A LA REGION "NORTH AMERICA"
# Out:
#     code                       name      continent         region  \
# 28   BMu                    Bermuda  North America  North America
# 37   CAN                     Canada  North America  North America
# 87   GRL                  Greenland  North America  North America
# 195  SPM  Saint Pierre and Miquelon  North America  North America
# 223  uSA              united States  North America  North America
#
#      surface_area  independence_year  population  life_expectancy        gnp  \
# 28           53.0                NaN       65000             76.9     2328.0
# 37      9970610.0             1867.0    31147000             79.4   598862.0
# 87      2166090.0                NaN       56000             68.1        0.0
# 195         242.0                NaN        7000             77.6        0.0
# 223     9363520.0             1776.0   278357000             77.1  8510700.0
#
#        gnp_old                 local_name  \
# 28      2190.0                    Bermuda
# ...

# %%
#Filtro por filas
filtro2=df.iloc[ 30:98 , : ]  #filas consecutivas
filtro2
#SE FILTRAN DATOS PARA QUE SE VEAN TODAS LAS COLUMNAS PERO, EN LAS FILAS, SOLO SE OBSERVEN LA INFORMACION DE LAS FILAS 30 A 97
# Out:
#    code                               name      continent  \
# 30  BRA                             Brazil  South America
# 31  BRB                           Barbados  North America
# 32  BRN                             Brunei           Asia
# 33  BTN                             Bhutan           Asia
# 34  BVT                      Bouvet Island     Antarctica
# ..  ...                                ...            ...
# 93  HMD  Heard Island and McDonald Islands     Antarctica
# 94  HND                           Honduras  North America
# 95  HRV                            Croatia         Europe
# 96  HTI                              Haiti  North America
# 97  HuN                            Hungary         Europe
#
#                        region  surface_area  independence_year  population  \
# 30              South America     8547403.0             1822.0   170115000
# 31                  Caribbean         430.0             1966.0      270000
# ...

# %%
#Filtro por columnas
filtro3=df.iloc[ : , [0,7,10]]  #columnas no consecutivas
filtro3
#SE FILTRAN DATOS PARA QUE SE VEAN TODAS LAS FILAS PERO, EN LAS COLUMNAS, SOLO SE OBSERVEN LOS DATOS DE LA PRIMERA, OCTAVA Y UNDÉICIMA COLUMNA
# Out:
#     code  life_expectancy             local_name
# 0    ABW             78.4                  Aruba
# 1    AFG             45.9  Afganistan/Afqanestan
# 2    AGO             38.3                 Angola
# 3    AIA             76.1               Anguilla
# 4    ALB             71.6              Shqiperia
# ..   ...              ...                    ...
# 234  YEM             59.8               Al-Yaman
# 235  YuG             72.4            Jugoslavija
# 236  ZAF             51.1           South Africa
# 237  ZMB             37.2                 Zambia
# 238  ZWE             37.8               Zimbabwe
#
# [239 rows x 3 columns]

# %%
df= pd.read_csv("CountryTable.csv", index_col=2)
df
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df.loc[["Europe","Asia"], ["code", "name","region"]]
filtro4
#LA COLUMNA 3 DE LA TABLA (CONTINENT) SE VUELVE EL ÍNDICE DE LA TABLA Y SE FILTRAN LOS DATOS QUE EN LAS FILAS SOLO SE VEA LA INFORMACION DE LOS CONTINENTES "EUROPE" Y "ASIA"
# Y EN LAS COLUMNAS SOLO SE VEA "CODE", "NAME" Y "REGION".
# Out:
#           code        name                     region
# continent
# Europe     ALB     Albania            Southern Europe
# Europe     AND     Andorra            Southern Europe
# Europe     AuT     Austria             Western Europe
# Europe     BEL     Belgium             Western Europe
# Europe     BGR    Bulgaria             Eastern Europe
# ...        ...         ...                        ...
# Asia       TuR      Turkey                Middle East
# Asia       TWN      Taiwan               Eastern Asia
# Asia       uZB  uzbekistan  Southern and Central Asia
# Asia       VNM     Vietnam             Southeast Asia
# Asia       YEM       Yemen                Middle East
#
# [97 rows x 3 columns]

# %%
#Filtro por cabecera
filtro5=df.head(25)
filtro5
#SE FILTRAN DATOS PARA SOLO APAREZCAN LAS PRIMERAS 25 FILAS
# Out:
#               code                         name                     region  \
# continent
# North America  ABW                        Aruba                  Caribbean
# Asia           AFG                  Afghanistan  Southern and Central Asia
# Africa         AGO                       Angola             Central Africa
# North America  AIA                     Anguilla                  Caribbean
# Europe         ALB                      Albania            Southern Europe
# Europe         AND                      Andorra            Southern Europe
# North America  ANT         Netherlands Antilles                  Caribbean
# Asia           ARE         united Arab Emirates                Middle East
# South America  ARG                    Argentina              South America
# Asia           ARM                      Armenia                Middle East
# Oceania        ASM               American Samoa                  Polynesia
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
#Filtro por comparacion
filtro6=df[df["life_expectancy"] > 78]
filtro6
#SE FILTRAN DATOS PARA QUE APAREZCAN LOS PAÍSES CON UN INDICE DE VIDA MAYOR A 78
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Europe         AND               Andorra            Southern Europe
# Oceania        AuS             Australia  Australia and New Zealand
# North America  CAN                Canada              North America
# Europe         CHE           Switzerland             Western Europe
# North America  CYM        Cayman Islands                  Caribbean
# Europe         ESP                 Spain            Southern Europe
# Europe         FRA                France             Western Europe
# Europe         FRO         Faroe Islands           Nordic Countries
# Europe         GIB             Gibraltar            Southern Europe
# Europe         GRC                Greece            Southern Europe
# Asia           HKG             Hong Kong               Eastern Asia
# Europe         ISL               Iceland           Nordic Countries
# ...

# %% [markdown]
# **FILTROS BASICOS CON CONETORES LOGICOS**

# %%
#Filtro Y
filtro7=df[(df["life_expectancy"] > 78) & (df["region"] == "Western Europe")]
filtro7
#SE FILTRAN DATOS PARA QUE APAREZCAN LOS PAÍSES CON UN INDICE DE VIDA MAYOR A 78 Y PAÍSES UBICADOS EN LA REGIÓN "WESTERN EUROPE"
# Out:
#           code           name          region  surface_area  \
# continent
# Europe     CHE    Switzerland  Western Europe       41284.0
# Europe     FRA         France  Western Europe      551500.0
# Europe     LIE  Liechtenstein  Western Europe         160.0
# Europe     MCO         Monaco  Western Europe           1.5
# Europe     NLD    Netherlands  Western Europe       41526.0
#
#            independence_year  population  life_expectancy        gnp  \
# continent
# Europe                1499.0     7160400             79.6   264478.0
# Europe                 843.0    59225700             78.8  1424285.0
# Europe                1806.0       32300             78.8     1119.0
# Europe                1861.0       34000             78.8      776.0
# Europe                1581.0    15864000             78.3   371362.0
#
#              gnp_old                      local_name          government_form  \
# continent
# ...

# %%
#Filtro o
filtro8=df[(df["life_expectancy"] > 78) | (df["government_form"] == "Republic")]
filtro8
#SE FILTRAN DATOS PARA QUE APAREZACAN LOS PAÍSES CON UN INDICE DE VIDA MAYOR A 78 O AQUELLOS PAÍSES EN LOS QUE SU FORMA DE GOBIERNO ES REPUBLICA
# Out:
#               code          name           region  surface_area  \
# continent
# North America  ABW         Aruba        Caribbean         193.0
# Africa         AGO        Angola   Central Africa     1246700.0
# Europe         ALB       Albania  Southern Europe       28748.0
# Europe         AND       Andorra  Southern Europe         468.0
# Asia           ARM       Armenia      Middle East       29800.0
# ...            ...           ...              ...           ...
# Oceania        VuT       Vanuatu        Melanesia       12189.0
# Asia           YEM         Yemen      Middle East      527968.0
# Africa         ZAF  South Africa  Southern Africa     1221037.0
# Africa         ZMB        Zambia   Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe   Eastern Africa      390757.0
#
#                independence_year  population  life_expectancy       gnp  \
# continent
# North America                NaN      103000             78.4     828.0
# ...

# %%
#Filtro not
filtro9=df[~(df["life_expectancy"] <= 78) & ~(df["government_form"] == "Republic")]
filtro9
#SE FILTRAN DATOS PARA QUE NO APAREZACAN LOS PAÍSES CON UN INDICE DE VIDA MENOR O IGUAL A 78 O AQUELLOS PAÍSES EN LOS QUE SU FORMA DE GOBIERNO ES REPUBLICA
# Out:
#               code                                          name  \
# continent
# North America  ABW                                         Aruba
# Europe         AND                                       Andorra
# Antarctica     ATA                                    Antarctica
# Antarctica     ATF                   French Southern territories
# Oceania        AuS                                     Australia
# Antarctica     BVT                                 Bouvet Island
# North America  CAN                                        Canada
# Oceania        CCK                       Cocos (Keeling) Islands
# Europe         CHE                                   Switzerland
# Oceania        CXR                              Christmas Island
# North America  CYM                                Cayman Islands
# Europe         ESP                                         Spain
# South America  FLK                              Falkland Islands
# ...

# %%
#Convertir archivoS filtrado a CSV
filtro1.to_csv("filtro1.csv")
filtro2.to_csv("filtro2.csv")
filtro3.to_csv("filtro3.csv")
filtro4.to_csv("filtro4.csv")
filtro5.to_csv("filtro5.csv")
filtro6.to_csv("filtro6.csv")
filtro7.to_csv("filtro7.csv")
filtro8.to_csv("filtro8.csv")
filtro9.to_csv("filtro9.csv")
#descargar archivoS filtrado en csv
from google.colab import files


files.download("filtro1.csv")
files.download("filtro2.csv")
files.download("filtro3.csv")
files.download("filtro4.csv")
files.download("filtro5.csv")
files.download("filtro6.csv")
files.download("filtro7.csv")
files.download("filtro8.csv")
files.download("filtro9.csv")
